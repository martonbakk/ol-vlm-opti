# %%
# !nvidia-smi
# Out:
# Tue Mar  3 14:54:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.59                 Driver Version: 591.59         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5080      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   40C    P8             21W /  360W |   15857MiB /  16303MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            7764    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            9640    C+G   ....0.3800.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           12348    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           13320    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           13700    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           16184    C+G   ...cord\app-1.0.9226\Discord.exe      N/A      |
# |    0   N/A  N/A           18320    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           20124    C+G   ...0.294.2.2\OverwolfBrowser.exe      N/A      |
# |    0   N/A  N/A           20816      C   ...indows-x86_64-none\python.exe      N/A      |
# |    0   N/A  N/A           21292    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22932    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           24848    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           26824    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           29544    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           35072    C+G   G:\overwolf\Overwolf.exe              N/A      |
# |    0   N/A  N/A           36228    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           37580    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           38192    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           38512    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           38852    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           44488    C+G   ...onsoftware\RadeonSoftware.exe      N/A      |
# |    0   N/A  N/A           44964    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           46800    C+G   ...64__zpdnekdrzrea0\Spotify.exe      N/A      |
# |    0   N/A  N/A           46888    C+G   ...Chrome\Application\chrome.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch version: 2.10.0+cu130
# CUDA available: True

# %%
from transformers import AutoProcessor, AutoModelForImageTextToText

# %% [markdown]
# ## Qwen3-VL
# ### Dense models:
# - Qwen3-VL 2B: qwen/Qwen3-VL-2B
# - Qwen3-VL 4B: qwen/Qwen3-VL-4B
# - Qwen3-VL 8B: qwen/Qwen3-VL-8B
# - Qwen3-VL 32B: qwen/Qwen3-VL-32B
#
# ### MoE:
# - Qwen3-VL 30B-A3B
# - Qwen3-VL 235B-A22B

# %%
model_id = "Qwen/Qwen3-VL-8B-Instruct"

processor = AutoProcessor.from_pretrained(model_id)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    device_map="cuda" if torch.cuda.is_available() else "cpu",
    cache_dir="./cache",
)

# %%
from torchinfo import summary

summary(model)
# Out:
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# Qwen3VLForConditionalGeneration                              --
# ├─Qwen3VLModel: 1-1                                          --
# │    └─Qwen3VLVisionModel: 2-1                               --
# │    │    └─Qwen3VLVisionPatchEmbed: 3-1                     1,770,624
# │    │    └─Embedding: 3-2                                   2,654,208
# │    │    └─Qwen3VLVisionRotaryEmbedding: 3-3                --
# │    │    └─ModuleList: 3-4                                  411,466,608
# │    │    └─Qwen3VLVisionPatchMerger: 3-5                    40,119,040
# │    │    └─ModuleList: 3-6                                  120,377,856
# │    └─Qwen3VLTextModel: 2-2                                 --
# │    │    └─Embedding: 3-7                                   622,329,856
# │    │    └─ModuleList: 3-8                                  6,946,071,552
# │    │    └─Qwen3VLTextRMSNorm: 3-9                          4,096
# │    │    └─Qwen3VLTextRotaryEmbedding: 3-10                 --
# ├─Linear: 1-2                                                622,329,856
# =====================================================================================
# Total params: 8,767,123,696
# Trainable params: 8,767,123,696
# Non-trainable params: 0
# =====================================================================================

# %%
print(model.config)
# Out:
# Qwen3VLConfig {
#   "architectures": [
#     "Qwen3VLForConditionalGeneration"
#   ],
#   "dtype": "bfloat16",
#   "image_token_id": 151655,
#   "model_type": "qwen3_vl",
#   "text_config": {
#     "attention_bias": false,
#     "attention_dropout": 0.0,
#     "bos_token_id": 151643,
#     "dtype": "bfloat16",
#     "eos_token_id": 151645,
#     "head_dim": 128,
#     "hidden_act": "silu",
#     "hidden_size": 4096,
#     "initializer_range": 0.02,
#     "intermediate_size": 12288,
#     "max_position_embeddings": 262144,
#     "model_type": "qwen3_vl_text",
#     "num_attention_heads": 32,
#     "num_hidden_layers": 36,
#     "num_key_value_heads": 8,
#     "pad_token_id": null,
#     "rms_norm_eps": 1e-06,
#     "rope_parameters": {
#       "mrope_interleaved": true,
#       "mrope_section": [
#         24,
#         20,
#         20
#       ],
#       "rope_theta": 5000000,
#       "rope_type": "default"
#     },
#     "use_cache": true,
#     "vocab_size": 151936
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "5.2.0",
#   "video_token_id": 151656,
#   "vision_config": {
#     "deepstack_visual_indexes": [
#       8,
#       16,
#       24
#     ],
#     "depth": 27,
#     "dtype": "bfloat16",
#     "hidden_act": "gelu_pytorch_tanh",
#     "hidden_size": 1152,
#     "in_channels": 3,
#     "initializer_range": 0.02,
#     "intermediate_size": 4304,
#     "model_type": "qwen3_vl",
#     "num_heads": 16,
#     "num_position_embeddings": 2304,
#     "out_hidden_size": 4096,
#     "patch_size": 16,
#     "spatial_merge_size": 2,
#     "temporal_patch_size": 2
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652
# }
